# %% [markdown]
# # SQLAlchemy – podstawy pracy z ORM
#
#
# [v2.0 docs](https://docs.sqlalchemy.org/en/20/tutorial/index.html)
#
# [v1.4 docs](https://docs.sqlalchemy.org/en/14/orm/tutorial.html)

# %%
import sqlalchemy


sqlalchemy.__version__  # wersja >=2.0.0
# Out:
# '2.0.44'

# %% [markdown]
# ## Połączenie z bazą danych
#
# ### `engine`

# %%
from sqlalchemy import create_engine


engine = create_engine("postgresql+psycopg://postgres:postgres@localhost:5432/task_manager", future=True)  # , echo=True <-- verbosity

# %% [markdown]
# ### `DeclarativeBase`

# %%
from sqlalchemy.orm import DeclarativeBase, declarative_base


# Starsze rozwiązanie, które wciąż działa, ale w przyszłości może zostać uznane za deprecated
Base = declarative_base()


# Obecnie rekomendowane rozwiązanie
class Base(DeclarativeBase):
    pass

# %% [markdown]
# ## Tabela i klasa jako model danych
#
# ### Tworzymy klasę
#
# Poniższy zapis definiowania kolumn nie jest zgodny z najnowszą dokumentacją, ale jest bardziej naturalny i od niego zaczniemy. W istniejącym kodzie częściej można sie spotkać właśnie z nim.
#
# Porównaj dokumentację:
# - [Starszy zapis](https://docs.sqlalchemy.org/en/14/tutorial/metadata.html#declaring-mapped-classes)
# - [Nowszy zapis](https://docs.sqlalchemy.org/en/20/tutorial/metadata.html#declaring-mapped-classes)

# %%
class Test:
    def __repr__(self):
        return "Reprezentacja obiektu"

# %%
t = Test()
t

# %%
t = Test()

# %%
t
# Out:
# Reprezentacja obiektu

# %%
from sqlalchemy import Column, Integer, String, Text, Boolean, Date, Float, DateTime
from datetime import datetime, timedelta


class User(Base):
    __tablename__ = "users"

    user_id = Column("id", Integer, primary_key=True, autoincrement=True)
    username = Column(String(50), unique=True, nullable=False)
    password = Column(Text, nullable=False)
    email = Column("email_address", String(255), unique=True, nullable=False)
    is_active = Column(Boolean, default=True)
    date_of_birth = Column(Date)
    created_at = Column(DateTime, default=datetime.now)
    
    def __repr__(self) -> str:
        return f"User(id={self.user_id}, username={self.username})"

# %% [markdown]
# ### Mapowanie klasy na tabelę
#
# Odpowiednik `CREATE`
#
# Aktualnie tabela `users` nie występuje w bazie danych.

# %%
Base.metadata.create_all(bind=engine)

# %% [markdown]
# Teraz już tam jest.

# %% [markdown]
# ### Tworzenie instancji klasy (i rekordów w tabeli)
#
# Odpowiednik `INSERT`

# %%
user1 = User(username="user1", password="password1", email="email.1@address.com")

# %%
user1
# Out:
# User(id=None, username=user1)

# %%
user1.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x7a48d743a3f0>,
#  'username': 'user1',
#  'password': 'password1',
#  'email': 'email.1@address.com'}

# %%
from sqlalchemy.orm import sessionmaker

SessionLocal = sessionmaker(engine, future=True)  # użycie nazwy SessionLocal jest konwencją, która zapobiega konfliktowi nazw z klasą Session, którą można zaimportować

# %% [markdown]
# **Sposób 1**
#
# Dodając rekord do tabeli tym sposobem musimy pamiętać o zamknięciu sesji po jej otwarciu. Zaletą jest to, że mamy dostęp do atrybutów obiektu nawet po zamknięciu sesji.

# %%
session = SessionLocal()

# %%
type(session)
# Out:
# sqlalchemy.orm.session.Session

# %%
session.add(user1)
session.commit()

# %%
user1.username
# Out:
# 'user1'

# %%
user1.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x7a48d743a3f0>,
#  'user_id': 1,
#  'email': 'email.1@address.com',
#  'username': 'user1',
#  'created_at': datetime.datetime(2025, 11, 20, 11, 46, 6, 688156),
#  'is_active': True,
#  'date_of_birth': None,
#  'password': 'password1'}

# %%
session.close()

# %%
user1.username
# Out:
# 'user1'

# %% [markdown]
# **Sposób 2 - rekomendowany**
#
# Dodając rekord do tabeli tym sposobem nie musimy ręcznie zamykać sesji. Jest on zalecany, jednak wiąże się z tym, że po dodaniu rekordu, odpowiadający mu obiekt zostaje odłączony od sesji.

# %%
user2 = User(username="user2", password="password2", email="email.2@address.com")
user2.username
# Out:
# 'user2'

# %%
with SessionLocal() as session:
    session.add(user2)
    session.commit()

# %%
user2
# Out:
# ---------------------------------------------------------------------------
# DetachedInstanceError                     Traceback (most recent call last)
# File ~/miniconda3/lib/python3.13/site-packages/IPython/core/formatters.py:770, in PlainTextFormatter.__call__(self, obj)
#     763 stream = StringIO()
#     764 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     765     self.max_width, self.newline,
#     766     max_seq_length=self.max_seq_length,
#     767     singleton_pprinters=self.singleton_printers,
#     768     type_pprinters=self.type_printers,
#     769     deferred_pprinters=self.deferred_printers)
# --> 770 printer.pretty(obj)
#     771 printer.flush()
#     772 return stream.getvalue()
#
# File ~/miniconda3/lib/python3.13/site-packages/IPython/lib/pretty.py:411, in RepresentationPrinter.pretty(self, obj)
#     400                         return meth(obj, self, cycle)
#     401                 if (
#     402                     cls is not object
#     403                     # check if cls defines __repr__
#    (...)    409                     and callable(_safe_getattr(cls, "__repr__", None))
#     410                 ):
# --> 411                     return _repr_pprint(obj, self, cycle)
#     413     return _default_pprint(obj, self, cycle)
#     414 finally:
#
# File ~/miniconda3/lib/python3.13/site-packages/IPython/lib/pretty.py:786, in _repr_pprint(obj, p, cycle)
#     784 """A pprint that just redirects to the normal repr function."""
#     785 # Find newlines and replace them with p.break_()
# --> 786 output = repr(obj)
#     787 lines = output.splitlines()
#     788 with p.group():
#
# Cell In[9], line 17, in User.__repr__(self)
#      16 def __repr__(self) -> str:
# ---> 17     return f"User(id={self.user_id}, username={self.username})"
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/attributes.py:569, in InstrumentedAttribute.__get__(self, instance, owner)
#     567 except AttributeError as err:
#     568     raise orm_exc.UnmappedInstanceError(instance) from err
# --> 569 return self.impl.get(state, dict_)
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/attributes.py:1096, in AttributeImpl.get(self, state, dict_, passive)
#    1093 if not passive & CALLABLES_OK:
#    1094     return PASSIVE_NO_RESULT
# -> 1096 value = self._fire_loader_callables(state, key, passive)
#    1098 if value is PASSIVE_NO_RESULT or value is NO_VALUE:
#    1099     return value
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/attributes.py:1126, in AttributeImpl._fire_loader_callables(self, state, key, passive)
#    1118 def _fire_loader_callables(
#    1119     self, state: InstanceState[Any], key: str, passive: PassiveFlag
#    1120 ) -> Any:
#    1121     if (
#    1122         self.accepts_scalar_loader
#    1123         and self.load_on_unexpire
#    1124         and key in state.expired_attributes
#    1125     ):
# -> 1126         return state._load_expired(state, passive)
#    1127     elif key in state.callables:
#    1128         callable_ = state.callables[key]
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/state.py:803, in InstanceState._load_expired(self, state, passive)
#     796 toload = self.expired_attributes.intersection(self.unmodified)
#     797 toload = toload.difference(
#     798     attr
#     799     for attr in toload
#     800     if not self.manager[attr].impl.load_on_unexpire
#     801 )
# --> 803 self.manager.expired_attribute_loader(self, toload, passive)
#     805 # if the loader failed, or this
#     806 # instance state didn't have an identity,
#     807 # the attributes still might be in the callables
#     808 # dict.  ensure they are removed.
#     809 self.expired_attributes.clear()
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/loading.py:1607, in load_scalar_attributes(mapper, state, attribute_names, passive)
#    1605 session = state.session
#    1606 if not session:
# -> 1607     raise orm_exc.DetachedInstanceError(
#    1608         "Instance %s is not bound to a Session; "
#    1609         "attribute refresh operation cannot proceed" % (state_str(state))
#    1610     )
#    1612 no_autoflush = bool(passive & attributes.NO_AUTOFLUSH)
#    1614 # in the case of inheritance, particularly concrete and abstract
#    1615 # concrete inheritance, the class manager might have some keys
#    1616 # of attributes on the superclass that we didn't actually map.
#    1617 # These could be mapped as "concrete, don't load" or could be completely
#    1618 # excluded from the mapping and we know nothing about them.  Filter them
#    1619 # here to prevent them from coming through.
#
# DetachedInstanceError: Instance <User at 0x7a48dabd02d0> is not bound to a Session; attribute refresh operation cannot proceed (Background on this error at: https://sqlalche.me/e/20/bhk3)

# %% [markdown]
# **Sposób 3 - dopuszczalny**
#
# W tym podejściu nie tworzymy obiektu, tylko od razu dodajemy określone wartości do tabeli.

# %%
from sqlalchemy import insert

# %%
stmt = insert(User).values(
        username="user3",
        password="password3",
        email="email.3@address.com"
    ).returning(User.user_id)


with SessionLocal() as session:
    result = session.execute(stmt)
    inserted_id = result.scalar_one()
    session.commit()

# %%
result

# %%
inserted_id
# Out:
# 3

# %% [markdown]
# ---

# %% [markdown]
# Stworzymy teraz kilku kolejnych użytkowników:

# %%
u4 = User(username="user_4", password="password_4", email="email_4")
u5 = User(username="user_5", password="password_5", email="email_5", date_of_birth="1990-04-05")
u6 = User(username="user_6", password="password_6", email="email_6", is_active=False)

# %%
with SessionLocal() as session:
    session.add_all([u4, u5, u6])
    session.commit()

# %% [markdown]
# ### Rollback
#
# Jeżeli podczas jakiejś operacji pojawi się błąd, nie będziemy w stanie wykonać następnej operacji, dopóki nie wykonamy tzw. rollbacka.
#
# **Uwaga:** jeśli używamy notacji z `with`, używanie rollbacka nie będzie konieczne

# %%
duplicate_user = User(username="user1", password="password_1", email="email_1")

# %%
session = SessionLocal()

# %%
session.add(duplicate_user)
session.commit()
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# File ~/miniconda3/lib/python3.13/site-packages/psycopg/cursor.py:97, in Cursor.execute(self, query, params, prepare, binary)
#      96 except e._NO_TRACEBACK as ex:
# ---> 97     raise ex.with_traceback(None)
#      98 return self
#
# UniqueViolation: duplicate key value violates unique constraint "users_username_key"
# DETAIL:  Key (username)=(user1) already exists.
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[37], line 2
#       1 session.add(duplicate_user)
# ----> 2 session.commit()
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/session.py:2030, in Session.commit(self)
#    2027 if trans is None:
#    2028     trans = self._autobegin_t()
# -> 2030 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     135 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#     139     raise
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/session.py:1311, in SessionTransaction.commit(self, _to_root)
#    1309 if self._state is not SessionTransactionState.PREPARED:
#    1310     with self._expect_state(SessionTransactionState.PREPARED):
# -> 1311         self._prepare_impl()
#    1313 if self._parent is None or self.nested:
#    1314     for conn, trans, should_commit, autoclose in set(
#    1315         self._connections.values()
#    1316     ):
#
# File <string>:2, in _prepare_impl(self)
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     135 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#     139     raise
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/session.py:1286, in SessionTransaction._prepare_impl(self)
#    1284     if self.session._is_clean():
#    1285         break
# -> 1286     self.session.flush()
#    1287 else:
#    1288     raise exc.FlushError(
#    1289         "Over 100 subsequent flushes have occurred within "
#    1290         "session.commit() - is an after_flush() hook "
#    1291         "creating new objects?"
#    1292     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/session.py:4331, in Session.flush(self, objects)
#    4329 try:
#    4330     self._flushing = True
# -> 4331     self._flush(objects)
#    4332 finally:
#    4333     self._flushing = False
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/session.py:4466, in Session._flush(self, objects)
#    4463     transaction.commit()
#    4465 except:
# -> 4466     with util.safe_reraise():
#    4467         transaction.rollback(_capture_exception=True)
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/session.py:4427, in Session._flush(self, objects)
#    4425 self._warn_on_events = True
#    4426 try:
# -> 4427     flush_context.execute()
#    4428 finally:
#    4429     self._warn_on_events = False
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/unitofwork.py:466, in UOWTransaction.execute(self)
#     464 else:
#     465     for rec in topological.sort(self.dependencies, postsort_actions):
# --> 466         rec.execute(self)
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/unitofwork.py:642, in SaveUpdateAll.execute(self, uow)
#     640 @util.preload_module("sqlalchemy.orm.persistence")
#     641 def execute(self, uow):
# --> 642     util.preloaded.orm_persistence.save_obj(
#     643         self.mapper,
#     644         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     645         uow,
#     646     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/persistence.py:93, in save_obj(base_mapper, states, uowtransaction, single)
#      81     update = _collect_update_commands(
#      82         uowtransaction, table, states_to_update
#      83     )
#      85     _emit_update_statements(
#      86         base_mapper,
#      87         uowtransaction,
#    (...)     90         update,
#      91     )
# ---> 93     _emit_insert_statements(
#      94         base_mapper,
#      95         uowtransaction,
#      96         mapper,
#      97         table,
#      98         insert,
#      99     )
#     101 _finalize_insert_update_commands(
#     102     base_mapper,
#     103     uowtransaction,
#    (...)    119     ),
#     120 )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/persistence.py:1233, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1227     result = connection.execute(
#    1228         statement.values(value_params),
#    1229         params,
#    1230         execution_options=execution_options,
#    1231     )
#    1232 else:
# -> 1233     result = connection.execute(
#    1234         statement,
#    1235         params,
#    1236         execution_options=execution_options,
#    1237     )
#    1239 primary_key = result.inserted_primary_key
#    1240 if primary_key is None:
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/sql/elements.py:526, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     524     if TYPE_CHECKING:
#     525         assert isinstance(self, Executable)
# --> 526     return connection._execute_clauseelement(
#     527         self, distilled_params, execution_options
#     528     )
#     529 else:
#     530     raise exc.ObjectNotExecutableError(self)
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1629 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1630     "compiled_cache", self.engine._compiled_cache
#    1631 )
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)   1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#    1654     self.dispatch.after_execute(
#    1655         self,
#    1656         elem,
#    (...)   1660         ret,
#    1661     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)   1978         context.executemany,
#    1979     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# File ~/miniconda3/lib/python3.13/site-packages/psycopg/cursor.py:97, in Cursor.execute(self, query, params, prepare, binary)
#      93         self._conn.wait(
#      94             self._execute_gen(query, params, prepare=prepare, binary=binary)
#      95         )
#      96 except e._NO_TRACEBACK as ex:
# ---> 97     raise ex.with_traceback(None)
#      98 return self
#
# IntegrityError: (psycopg.errors.UniqueViolation) duplicate key value violates unique constraint "users_username_key"
# DETAIL:  Key (username)=(user1) already exists.
# [SQL: INSERT INTO users (username, password, email_address, is_active, date_of_birth, created_at) VALUES (%(username)s::VARCHAR, %(password)s::VARCHAR, %(email_address)s::VARCHAR, %(is_active)s, %(date_of_birth)s::DATE, %(created_at)s::TIMESTAMP WITHOUT TIME ZONE) RETURNING users.id]
# [parameters: {'username': 'user1', 'password': 'password_1', 'email_address': 'email_1', 'is_active': True, 'date_of_birth': None, 'created_at': datetime.datetime(2025, 11, 20, 11, 7, 14, 267206)}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %% [markdown]
# Teraz dodanie nowego (poprawnego) użytkownika również skończy się błędem:

# %%
new_user = User(username="new_user_1", password="new_password_1", email="new_email_1")

session.add(new_user)
session.commit()
# Out:
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[38], line 4
#       1 new_user = User(username="new_user_1", password="new_password_1", email="new_email_1")
#       3 session.add(new_user)
# ----> 4 session.commit()
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/session.py:2030, in Session.commit(self)
#    2027 if trans is None:
#    2028     trans = self._autobegin_t()
# -> 2030 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/state_changes.py:101, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#      95 current_state = self._state
#      97 if (
#      98     has_prerequisite_states
#      99     and current_state not in prerequisite_state_collection
#     100 ):
# --> 101     self._raise_for_prerequisite_state(fn.__name__, current_state)
#     103 next_state = self._next_state
#     104 existing_fn = self._current_fn
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/session.py:971, in SessionTransaction._raise_for_prerequisite_state(self, operation_name, state)
#     969 if state is SessionTransactionState.DEACTIVE:
#     970     if self._rollback_exception:
# --> 971         raise sa_exc.PendingRollbackError(
#     972             "This Session's transaction has been rolled back "
#     973             "due to a previous exception during flush."
#     974             " To begin a new transaction with this Session, "
#     975             "first issue Session.rollback()."
#     976             f" Original exception was: {self._rollback_exception}",
#     977             code="7s2a",
#     978         )
#     979     else:
#     980         raise sa_exc.InvalidRequestError(
#     981             "This session is in 'inactive' state, due to the "
#     982             "SQL transaction being rolled back; no further SQL "
#     983             "can be emitted within this transaction."
#     984         )
#
# PendingRollbackError: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (psycopg.errors.UniqueViolation) duplicate key value violates unique constraint "users_username_key"
# DETAIL:  Key (username)=(user1) already exists.
# [SQL: INSERT INTO users (username, password, email_address, is_active, date_of_birth, created_at) VALUES (%(username)s::VARCHAR, %(password)s::VARCHAR, %(email_address)s::VARCHAR, %(is_active)s, %(date_of_birth)s::DATE, %(created_at)s::TIMESTAMP WITHOUT TIME ZONE) RETURNING users.id]
# [parameters: {'username': 'user1', 'password': 'password_1', 'email_address': 'email_1', 'is_active': True, 'date_of_birth': None, 'created_at': datetime.datetime(2025, 11, 20, 11, 7, 14, 267206)}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj) (Background on this error at: https://sqlalche.me/e/20/7s2a)

# %% [markdown]
# Należy wykonać rollback:

# %%
session.rollback()
# Out:
# /tmp/ipykernel_2993562/1760783211.py:1: SAWarning: Session's state has been changed on a non-active transaction - this state will be discarded.
#   session.rollback()

# %%
new_user = User(username="new_user_1", password="new_password_1", email="new_email_1")

session.add(new_user)
session.commit()

# %%
session.close()

# %% [markdown]
# > **ZADANIA**

# %% [markdown]
# ## Wyciąganie danych z tabeli
#
# Odpowiednik `SELECT`
#
# ### Wyciąganie wszystkich danych
#
# Odpowiednik `SELECT * FROM table`

# %%
from sqlalchemy import select

# %%
with SessionLocal() as session:
    stmt = select(User)
    # print("!", session.scalars(stmt))
    
    results = session.scalars(stmt).all()

# %%
results
# Out:
# [User(id=1, username=user1),
#  User(id=2, username=user2),
#  User(id=3, username=user3),
#  User(id=4, username=user_4),
#  User(id=5, username=user_5),
#  User(id=6, username=user_6)]

# %%
results[0].email
# Out:
# 'email.1@address.com'

# %% [markdown]
# Poniżej znajduje się stary zapis (zakomentowany). Wciąż działa, ale w nowej wersji SQLAlchemy nie jest rekomendowany.

# %%
# results = session.query(User).all()
# results

# %% [markdown]
# ### Wyciąganie niektórych kolumn
#
# Odpowiednik `SELECT column1, column2, FROM table`
#
# Wynikiem nie jest lista obiektów, tylko lista tupli.

# %%
with SessionLocal() as session:
    stmt = select(User.username, User.email)
    results = session.execute(stmt).all()
    # results = session.execute(stmt).mappings().all()  # <-- słowniki

# %%
results
# Out:
# [{'username': 'user1', 'email': 'email.1@address.com'},
#  {'username': 'user2', 'email': 'email.2@address.com'},
#  {'username': 'user3', 'email': 'email.3@address.com'},
#  {'username': 'user_4', 'email': 'email_4'},
#  {'username': 'user_5', 'email': 'email_5'},
#  {'username': 'user_6', 'email': 'email_6'}]

# %% [markdown]
# ### Sprawdzenie wygenerowanego kodu SQL
#
# Zapytania napisane w ORM można zamienić na czysty SQL. Robimy to w następujący sposób.

# %%
with SessionLocal() as session:
    stmt = select(User.username, User.email)

    sql = stmt.compile(
        session.get_bind(),
        compile_kwargs={"literal_binds": True}
    )

# %%
print(sql)
# Out:
# SELECT users.username, users.email_address
# FROM users

# %% [markdown]
# ### Filtrowanie danych
#
# Odpowiednik `WHERE`
#
# Aby przefiltrować dane, musimy wywołać funkcję `where` na funkcji `select`.

# %%
with SessionLocal() as session:
    stmt = select(User).where(User.user_id == 2)
    results = session.scalars(stmt).all()

results
# Out:
# [User(id=2, username=user2)]

# %% [markdown]
# Zamiast funkcji `all()` na końcu możemy użyć funkcji `first()` lub `one()`.
#
# Pierwsza z nich zwraca pierwszy rekord spośród zbioru jednego lub więcej rekordów. Druga – również zwraca pierwszy wynik, ale gdyby zapytanie zwróciło ich więcej, spowoduje błąd.

# %%
with SessionLocal() as session:
    stmt = select(User).where(User.user_id == 2)
    result = session.scalars(stmt).first()

result
# Out:
# User(id=2, username=user2)

# %%
with SessionLocal() as session:
    stmt = select(User).where(User.user_id >= 2)
    result = session.scalars(stmt).first()

result
# Out:
# User(id=2, username=user2)

# %% [markdown]
# ---

# %%
with SessionLocal() as session:
    stmt = select(User).where(User.user_id == 2)
    result = session.scalars(stmt).one()

result
# Out:
# User(id=2, username=user2)

# %%
with SessionLocal() as session:
    stmt = select(User).where(User.user_id >= 2)
    result = session.scalars(stmt).one()

result
# Out:
# ---------------------------------------------------------------------------
# MultipleResultsFound                      Traceback (most recent call last)
# Cell In[93], line 3
#       1 with SessionLocal() as session:
#       2     stmt = select(User).where(User.user_id >= 2)
# ----> 3     result = session.scalars(stmt).one()
#       5 result
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/result.py:1815, in ScalarResult.one(self)
#    1807 def one(self) -> _R:
#    1808     """Return exactly one object or raise an exception.
#    1809
#    1810     Equivalent to :meth:`_engine.Result.one` except that
#    (...)   1813
#    1814     """
# -> 1815     return self._only_one_row(
#    1816         raise_for_second_row=True, raise_for_none=True, scalar=False
#    1817     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/result.py:813, in ResultInternal._only_one_row(self, raise_for_second_row, raise_for_none, scalar)
#     811     if next_row is not _NO_ROW:
#     812         self._soft_close(hard=True)
# --> 813         raise exc.MultipleResultsFound(
#     814             "Multiple rows were found when exactly one was required"
#     815             if raise_for_none
#     816             else "Multiple rows were found when one or none "
#     817             "was required"
#     818         )
#     819 else:
#     820     # if we checked for second row then that would have
#     821     # closed us :)
#     822     self._soft_close(hard=True)
#
# MultipleResultsFound: Multiple rows were found when exactly one was required

# %% [markdown]
# ### Łączenie warunków spójnikami logicznymi
#
#
# Podczas filtrowania możemy łączyć warunki spójnikami `AND` oraz `OR`.

# %% [markdown]
# **`AND`**

# %%
with SessionLocal() as session:
    stmt = select(User).where(
        User.is_active.is_(True),
        User.date_of_birth.is_(None)
    )
    results = session.scalars(stmt).all()


results
# Out:
# [User(id=1, username=user1),
#  User(id=2, username=user2),
#  User(id=3, username=user3),
#  User(id=4, username=user_4)]

# %%
len(results)
# Out:
# 4

# %% [markdown]
# **`OR`**

# %%
from sqlalchemy import or_, and_

# %%
with SessionLocal() as session:
    stmt = select(User).where(
        or_(
            User.is_active.is_(True),
            User.date_of_birth.is_(None)
        )
    )
    results = session.scalars(stmt).all()

results
# Out:
# [User(id=1, username=user1),
#  User(id=2, username=user2),
#  User(id=3, username=user3),
#  User(id=4, username=user_4),
#  User(id=5, username=user_5),
#  User(id=6, username=user_6)]

# %%
len(results)
# Out:
# 6

# %% [markdown]
# ### Filtrowanie elementów należących do zbioru

# %%
with SessionLocal() as session:
    stmt_in = select(User).where(
        User.username.in_(["user_1", "user_2", "user_3"])
    )
    users_in = session.scalars(stmt_in).all()

    
    stmt_not_in = select(User).where(
        User.username.not_in(["user_1", "user_2", "user_3"])
    )
    users_not_in = session.scalars(stmt_not_in).all()

# %%
users_in
# Out:
# []

# %%
users_not_in
# Out:
# [User(id=1, username=user1),
#  User(id=2, username=user2),
#  User(id=3, username=user3),
#  User(id=4, username=user_4),
#  User(id=5, username=user_5),
#  User(id=6, username=user_6)]

# %% [markdown]
# ### Sortowanie wyników
#
# Odpowiednik `ORDER BY`

# %% [markdown]
# Sortowanie rosnące po `created_at`:

# %%
with SessionLocal() as session:
    stmt = select(User).order_by(User.created_at)
    sorted_users = session.scalars(stmt).all()

# %%
sorted_users
# Out:
# [User(id=1, username=user1),
#  User(id=2, username=user2),
#  User(id=3, username=user3),
#  User(id=4, username=user_4),
#  User(id=5, username=user_5),
#  User(id=6, username=user_6)]

# %% [markdown]
# Sortowanie malejące po `created_at`:

# %%
from sqlalchemy import desc


with SessionLocal() as session:
    stmt = select(User).order_by(desc(User.created_at))
    sorted_users_desc = session.scalars(stmt).all()

# %%
sorted_users_desc
# Out:
# [User(id=6, username=user_6),
#  User(id=5, username=user_5),
#  User(id=4, username=user_4),
#  User(id=3, username=user3),
#  User(id=2, username=user2),
#  User(id=1, username=user1)]

# %% [markdown]
# Sortowanie po `date_of_birth` a następnie po `is_active`:

# %%
with SessionLocal() as session:
    stmt = select(User).order_by(User.date_of_birth, User.is_active)
    sorted_users = session.scalars(stmt).all()

# %%
sorted_users
# Out:
# [User(id=5, username=user_5),
#  User(id=6, username=user_6),
#  User(id=1, username=user1),
#  User(id=2, username=user2),
#  User(id=3, username=user3),
#  User(id=4, username=user_4)]

# %%
with SessionLocal() as session:
    stmt = select(User).order_by(desc(User.date_of_birth), User.is_active)
    sorted_users = session.scalars(stmt).all()

# %%
sorted_users
# Out:
# [User(id=6, username=user_6),
#  User(id=1, username=user1),
#  User(id=2, username=user2),
#  User(id=3, username=user3),
#  User(id=4, username=user_4),
#  User(id=5, username=user_5)]

# %% [markdown]
# ### Groupby
#
# Odpowiednik `GROUP BY`

# %%
from sqlalchemy import func

# %% [markdown]
# Liczba userów aktywnych/nieaktywnych

# %%
with SessionLocal() as session:
    stmt = select(User.is_active, func.count(User.user_id)).group_by(User.is_active)
    result = session.execute(stmt).all()

# %%
result

# %% [markdown]
# Średnia długość hasła dla userów aktywnych/niekatywnych

# %%
with SessionLocal() as session:
    stmt = select(
        User.is_active,
        func.avg(func.length(User.password))
    ).group_by(User.is_active)
    
    result = session.execute(stmt).all()

# %%
result

# %% [markdown]
# ### Funkcje matematyczne
#
# Wyciągając dane, możemy je przekształcać funkcjami matematycznymi

# %%
with SessionLocal() as session:
    stmt = select(func.sqrt(User.user_id))
    sqrt_user_id = session.scalars(stmt).all()

sqrt_user_id

# %%
with SessionLocal() as session:
    avg_user_id = session.scalar(
        select(func.avg(User.user_id))
    )

avg_user_id

# %%
func.exp, func.log, func.log2

# %% [markdown]
# ### Złożone zapytania
#
# Powyższe elementy możemy łączyć tworząc złożone zapytania.

# %%
with SessionLocal() as session:
    stmt = (
        select(
            User.is_active,
            func.count(User.user_id).label("user_count"),
            func.avg(func.length(User.password)).label("avg_password_length")
        )
        .where(User.created_at.is_not(None))
        .group_by(User.is_active)
        .order_by(desc("avg_password_length"))
    )
    result = session.execute(stmt).all()


result
# Out:
# [(False, 1, Decimal('10.0000000000000000')),
#  (True, 5, Decimal('9.4000000000000000'))]

# %% [markdown]
# > **ZADANIA**

# %% [markdown]
# ## Modyfikacja rekordów
#
# `UPDATE`

# %%
with SessionLocal() as session:
    user = session.scalars(
        select(User).where(User.user_id == 1)
    ).first()

    if user:
        user.username = "username_modified"
        session.commit()
    else:
        print("Użytkownik o podanym user_id nie istnieje")

# %% [markdown]
# ## Usuwanie rekordów i tabeli
#
# `DELETE`

# %%
with SessionLocal() as session:
    user = session.scalars(
        select(User).where(User.user_id == 1)
    ).first()

    if user:
        session.delete(user)
        session.commit()
    else:
        print("Użytkownik o podanym user_id nie istnieje")

# %% [markdown]
# `TRUNCATE`
#
# SQLAlchemy nie udostępnia obiektowej wersji polecenia `TRUNCATE`. Możemy więc albo wywołać na sesji czystego SQLa zawierającego odpowiednie zapytanie, albo zaimplementować własna metode w klasie `User`.

# %%
from sqlalchemy import text

# %%
with SessionLocal() as session:
    session.execute(text("TRUNCATE TABLE users RESTART IDENTITY;"))
    # RESTART IDENTITY - restartuje sekwencję wartości w kolumnie id
    
    session.commit()

# %%
u1 = User(username="user_1", password="password_1", email="email_1")
u2 = User(username="user_2", password="password_2", email="email_2", date_of_birth="1990-04-05")
u3 = User(username="user_3", password="password_3", email="email_3", is_active=False)


with SessionLocal() as session:
    session.add_all([u1, u2, u3])
    session.commit()

# %% [markdown]
# ---

# %%
class User(Base):
    __tablename__ = "users1"

    user_id = Column("id", Integer, primary_key=True, autoincrement=True)
    username = Column(String(50), unique=True, nullable=False)
    password = Column(Text, nullable=False)
    email = Column("email_address", String(255), unique=True, nullable=False)
    is_active = Column(Boolean, default=True)
    date_of_birth = Column(Date)
    created_at = Column(DateTime, default=datetime.now)
    
    
    def __repr__(self) -> str:
        return f"User(id={self.user_id}, username={self.username})"

    @staticmethod
    def truncate():
        with SessionLocal() as session:
            session.execute(text("TRUNCATE TABLE users RESTART IDENTITY"))
            session.commit()
# Out:
# /tmp/ipykernel_2993562/2137287843.py:1: SAWarning: This declarative base already contains a class with the same class name and module name as __main__.User, and will be replaced in the string-lookup table.
#   class User(Base):

# %%
User.truncate()
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# File ~/miniconda3/lib/python3.13/site-packages/psycopg/cursor.py:97, in Cursor.execute(self, query, params, prepare, binary)
#      96 except e._NO_TRACEBACK as ex:
# ---> 97     raise ex.with_traceback(None)
#      98 return self
#
# UndefinedTable: relation "users" does not exist
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 User.truncate()
#
# Cell In[128], line 19, in User.truncate()
#      16 @staticmethod
#      17 def truncate():
#      18     with SessionLocal() as session:
# ---> 19         session.execute(text("TRUNCATE TABLE users RESTART IDENTITY"))
#      20         session.commit()
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/session.py:2351, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#    2291 def execute(
#    2292     self,
#    2293     statement: Executable,
#    (...)   2299     _add_event: Optional[Any] = None,
#    2300 ) -> Result[Any]:
#    2301     r"""Execute a SQL expression construct.
#    2302
#    2303     Returns a :class:`_engine.Result` object representing
#    (...)   2349
#    2350     """
# -> 2351     return self._execute_internal(
#    2352         statement,
#    2353         params,
#    2354         execution_options=execution_options,
#    2355         bind_arguments=bind_arguments,
#    2356         _parent_execute_state=_parent_execute_state,
#    2357         _add_event=_add_event,
#    2358     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/orm/session.py:2258, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2249     result: Result[Any] = compile_state_cls.orm_execute_statement(
#    2250         self,
#    2251         statement,
#    (...)   2255         conn,
#    2256     )
#    2257 else:
# -> 2258     result = conn.execute(
#    2259         statement, params or {}, execution_options=execution_options
#    2260     )
#    2262 if _scalar_result:
#    2263     return result.scalar()
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/sql/elements.py:526, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     524     if TYPE_CHECKING:
#     525         assert isinstance(self, Executable)
# --> 526     return connection._execute_clauseelement(
#     527         self, distilled_params, execution_options
#     528     )
#     529 else:
#     530     raise exc.ObjectNotExecutableError(self)
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1629 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1630     "compiled_cache", self.engine._compiled_cache
#    1631 )
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)   1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#    1654     self.dispatch.after_execute(
#    1655         self,
#    1656         elem,
#    (...)   1660         ret,
#    1661     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)   1978         context.executemany,
#    1979     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# File ~/miniconda3/lib/python3.13/site-packages/psycopg/cursor.py:97, in Cursor.execute(self, query, params, prepare, binary)
#      93         self._conn.wait(
#      94             self._execute_gen(query, params, prepare=prepare, binary=binary)
#      95         )
#      96 except e._NO_TRACEBACK as ex:
# ---> 97     raise ex.with_traceback(None)
#      98 return self
#
# ProgrammingError: (psycopg.errors.UndefinedTable) relation "users" does not exist
# [SQL: TRUNCATE TABLE users RESTART IDENTITY]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# `DROP`

# %%
User.__table__.drop(engine)
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# File ~/miniconda3/lib/python3.13/site-packages/psycopg/cursor.py:97, in Cursor.execute(self, query, params, prepare, binary)
#      96 except e._NO_TRACEBACK as ex:
# ---> 97     raise ex.with_traceback(None)
#      98 return self
#
# UndefinedTable: table "users1" does not exist
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 User.__table__.drop(engine)
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/sql/schema.py:1300, in Table.drop(self, bind, checkfirst)
#    1290 def drop(self, bind: _CreateDropBind, checkfirst: bool = False) -> None:
#    1291     """Issue a ``DROP`` statement for this
#    1292     :class:`_schema.Table`, using the given
#    1293     :class:`.Connection` or :class:`.Engine` for connectivity.
#    (...)   1298
#    1299     """
# -> 1300     bind._run_ddl_visitor(ddl.SchemaDropper, self, checkfirst=checkfirst)
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:3252, in Engine._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    3245 def _run_ddl_visitor(
#    3246     self,
#    3247     visitorcallable: Type[InvokeDDLBase],
#    3248     element: SchemaVisitable,
#    3249     **kwargs: Any,
#    3250 ) -> None:
#    3251     with self.begin() as conn:
# -> 3252         conn._run_ddl_visitor(visitorcallable, element, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2459, in Connection._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    2445 def _run_ddl_visitor(
#    2446     self,
#    2447     visitorcallable: Type[InvokeDDLBase],
#    2448     element: SchemaVisitable,
#    2449     **kwargs: Any,
#    2450 ) -> None:
#    2451     """run a DDL visitor.
#    2452
#    2453     This method is only here so that the MockConnection can change the
#    2454     options given to the visitor so that "checkfirst" is skipped.
#    2455
#    2456     """
#    2457     visitorcallable(
#    2458         dialect=self.dialect, connection=self, **kwargs
# -> 2459     ).traverse_single(element)
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/sql/visitors.py:661, in ExternalTraversal.traverse_single(self, obj, **kw)
#     659 meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     660 if meth:
# --> 661     return meth(obj, **kw)
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/sql/ddl.py:1209, in SchemaDropper.visit_table(self, table, drop_ok, _is_metadata_operation, _ignore_sequences)
#    1202     return
#    1204 with self.with_ddl_events(
#    1205     table,
#    1206     checkfirst=self.checkfirst,
#    1207     _is_metadata_operation=_is_metadata_operation,
#    1208 ):
# -> 1209     DropTable(table)._invoke_with(self.connection)
#    1211     # traverse client side defaults which may refer to server-side
#    1212     # sequences. noting that some of these client side defaults may
#    1213     # also be set up as server side defaults
#    (...)   1216     # #associating-a-sequence-as-the-server-side-
#    1217     # default), so have to be dropped after the table is dropped.
#    1218     for column in table.columns:
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/sql/ddl.py:321, in ExecutableDDLElement._invoke_with(self, bind)
#     319 def _invoke_with(self, bind):
#     320     if self._should_execute(self.target, bind):
# --> 321         return bind.execute(self)
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/sql/ddl.py:187, in ExecutableDDLElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     184 def _execute_on_connection(
#     185     self, connection, distilled_params, execution_options
#     186 ):
# --> 187     return connection._execute_ddl(
#     188         self, distilled_params, execution_options
#     189     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1530, in Connection._execute_ddl(self, ddl, distilled_parameters, execution_options)
#    1525 dialect = self.dialect
#    1527 compiled = ddl.compile(
#    1528     dialect=dialect, schema_translate_map=schema_translate_map
#    1529 )
# -> 1530 ret = self._execute_context(
#    1531     dialect,
#    1532     dialect.execution_ctx_cls._init_ddl,
#    1533     compiled,
#    1534     None,
#    1535     exec_opts,
#    1536     compiled,
#    1537 )
#    1538 if self._has_events or self.engine._has_events:
#    1539     self.dispatch.after_execute(
#    1540         self,
#    1541         ddl,
#    (...)   1545         ret,
#    1546     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)   1978         context.executemany,
#    1979     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# File ~/miniconda3/lib/python3.13/site-packages/psycopg/cursor.py:97, in Cursor.execute(self, query, params, prepare, binary)
#      93         self._conn.wait(
#      94             self._execute_gen(query, params, prepare=prepare, binary=binary)
#      95         )
#      96 except e._NO_TRACEBACK as ex:
# ---> 97     raise ex.with_traceback(None)
#      98 return self
#
# ProgrammingError: (psycopg.errors.UndefinedTable) table "users1" does not exist
# [SQL:
# DROP TABLE users1]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# > **ZADANIA**
