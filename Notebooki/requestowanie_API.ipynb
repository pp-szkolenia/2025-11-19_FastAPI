# %%
import requests
from urllib.parse import urljoin

# %%
main_url = "http://localhost:8000"

# %% [markdown]
# ## `get`

# %%
response = requests.get(main_url)
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'Hello World!'}

# %% [markdown]
# **Tasks**

# %%
response = requests.get(urljoin(main_url, "tasks"))
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'result': [{'task_id': 1,
#    'description': 'Opis kolejnego zadania',
#    'priority': 2,
#    'is_completed': True},
#   {'task_id': 2,
#    'description': 'Updated description',
#    'priority': 4,
#    'is_completed': False},
#   {'task_id': 4,
#    'description': 'Task 3',
#    'priority': 4,
#    'is_completed': False},
#   {'task_id': 6,
#    'description': 'Opis zadania',
#    'priority': 2,
#    'is_completed': True}]}

# %%
response.url
# Out:
# 'http://localhost:8000/tasks'

# %%
task_id = 6

response = requests.get(urljoin(main_url, f"tasks/{task_id}"))
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'result': {'task_id': 6,
#   'description': 'Opis zadania',
#   'priority': 2,
#   'is_completed': True}}

# %% [markdown]
# ## `post`

# %%
task = {"description": "Opis from requests", "priority": 3}

# %%
response = requests.post(urljoin(main_url, "tasks"), json=task)

# %%
response.json()
# Out:
# {'message': 'New task added',
#  'details': {'task_id': 6,
#   'description': 'Opis from requests',
#   'priority': 3,
#   'is_completed': False}}

# %% [markdown]
# ## `put`

# %%
updated_task = {"description": "Opis zadania", "priority": 2, "is_completed": True}

# %%
task_id = 6

response = requests.put(urljoin(main_url, f"tasks/{task_id}"), json=updated_task)

# %%
response.json()
# Out:
# {'message': 'Task with id 6 updated',
#  'new_value': {'task_id': 6,
#   'description': 'Opis zadania',
#   'priority': 2,
#   'is_completed': True}}

# %% [markdown]
# ## `delete`

# %%
task_id = 1

response = requests.delete(urljoin(main_url, f"tasks/{task_id}"))

# %%
response.text
# Out:
# ''
